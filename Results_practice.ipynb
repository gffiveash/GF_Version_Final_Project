# %% [markdown]
# <a href="https://colab.research.google.com/github/gffiveash/GF_Version_Final_Project/blob/main/Results_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/sterlinggutterman/Final-Project
# Out:
# Cloning into 'Final-Project'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 44 (delta 12), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (44/44), 36.88 MiB | 9.10 MiB/s, done.
# Resolving deltas: 100% (12/12), done.

# %%
import pandas as pd

# %%
df=pd.read_parquet('/content/Final-Project/full_df (2).parquet')

# %%
df.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    361493       27    prior             1          3                  9
# 1   1662354       27    prior             2          2                 17
# 2   1662354       27    prior             2          2                 17
# 3   1662354       27    prior             2          2                 17
# 4   1662354       27    prior             2          2                 17
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN       25718                  1          0
# 1                     6.0       30776                  1          0
# 2                     6.0        9604                  2          0
# 3                     6.0        6287                  3          0
# 4                     6.0       20947                  4          0
#
#   reordered_yes/no order_day  total_order_count  \
# 0               no   tuesday                 81
# ...

# %%
df['department'].unique()
# Out:
# array(['beverages', 'dairy eggs', 'international', 'snacks', 'produce',
#        'personal care', 'household', 'pantry', 'breakfast', 'bakery',
#        'deli', 'frozen', 'dry goods pasta', 'canned goods', 'babies',
#        'other', 'alcohol', 'missing', 'meat seafood', 'bulk', 'pets'],
#       dtype=object)

# %%
pd.crosstab(df['days_since_prior_order'],df['department'])
# Out:
# department              alcohol  babies  bakery  beverages  breakfast  bulk  \
# days_since_prior_order
# 0.0                         937     861    4011      10615       2715   290
# 1.0                        2305    3696   12075      30436       6824   526
# 2.0                        2398    7446   16062      38116       8714   610
# 3.0                        1858    8480   16568      36504       9215   592
# 4.0                        1371    6679   13415      29550       7876   471
# 5.0                         739    4759    9030      20369       5315   330
# 6.0                         599    2956    5970      14026       3732   210
# 7.0                         552    1942    4330      10407       2991   167
# 8.0                         196     915    2020       4449       1259    67
# 9.0                          95     534    1131       2378        667    28
# 10.0                         72     408     853       1861        496    29
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['days_since_prior_order']=df['days_since_prior_order'].fillna(0)

# %%
y=df['days_since_prior_order']
X=pd.get_dummies(df['order_day'],dtype='int')
print(X.head())
from sklearn.linear_model import LinearRegression
reg=LinearRegression(fit_intercept=False).fit(X,y)
results=pd.DataFrame({'variable':reg.feature_names_in_, 'coefficient': reg.coef_})
print(results)
# Out:
#    friday  monday  saturday  sunday  thursday  tuesday  wednesday
# 0       0       0         0       0         0        1          0
# 1       0       1         0       0         0        0          0
# 2       0       1         0       0         0        0          0
# 3       0       1         0       0         0        0          0
# 4       0       1         0       0         0        0          0
#     variable  coefficient
# 0     friday     3.888866
# 1     monday     3.802638
# 2   saturday     3.995510
# 3     sunday     4.092941
# 4   thursday     3.466639
# 5    tuesday     3.453142
# 6  wednesday     3.409978

# %%
y=df['days_since_prior_order']
X=pd.get_dummies(df['order_hour_of_day'])
reg=LinearRegression(fit_intercept=False).fit(X,y)
results=pd.DataFrame({'variable':X.columns, 'coefficient': reg.coef_})
print(results)

#print(reg.intercept_)
# Out:
#     variable  coefficient
# 0          0     4.425985
# 1          1     4.311062
# 2          2     4.720145
# 3          3     4.801829
# 4          4     5.714744
# 5          5     4.588879
# 6          6     4.268573
# 7          7     4.156661
# 8          8     4.037447
# 9          9     3.955405
# 10        10     3.871287
# 11        11     3.799086
# 12        12     3.669735
# 13        13     3.684167
# 14        14     3.638376
# 15        15     3.583409
# 16        16     3.514205
# 17        17     3.583849
# 18        18     3.625757
# 19        19     3.528220
# 20        20     3.472156
# 21        21     3.351170
# 22        22     3.407847
# 23        23     3.313793
