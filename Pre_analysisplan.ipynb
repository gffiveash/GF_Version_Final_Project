# %% [markdown]
# <a href="https://colab.research.google.com/github/gffiveash/GF_Version_Final_Project/blob/main/Pre_analysisplan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/gffiveash/GF_Version_Final_Project
# Out:
# Cloning into 'GF_Version_Final_Project'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 11 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (11/11), 21.68 MiB | 15.01 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
import pandas as pd

# %%
df=pd.read_parquet('/content/GF_Version_Final_Project/full_df (2).parquet')

# %%
df.head(15)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0     361493       27    prior             1          3                  9
# 1    1662354       27    prior             2          2                 17
# 2    1662354       27    prior             2          2                 17
# 3    1662354       27    prior             2          2                 17
# 4    1662354       27    prior             2          2                 17
# 5    1662354       27    prior             2          2                 17
# 6    1662354       27    prior             2          2                 17
# 7     965677       27    prior             3          3                  8
# 8     965677       27    prior             3          3                  8
# 9    2842504       27    prior             4          5                 13
# 10   2842504       27    prior             4          5                 13
# ...
